# %% [markdown]
# # run fimo

# %%
nohup fimo --max-strand -o epithelial_gap_fimo  Ray2013_rbp_Homo_sapiens.dna_encoded.meme /mnt/ruiyanhou/nfs_share2/three_primer/ESCC/ERCC_part/microRNA/RBP/gap_sequence.fa &

# %% [markdown]
# # get binding frequency

# %%
import pandas as pd

# %%
onedf=pd.read_csv('/mnt/ruiyanhou/nfs_share2/three_primer/ESCC/ERCC_part/RBP/epithelial_gap_fimo/fimo.txt',delimiter='\t')
onedf
# Out:
#       #pattern name              sequence name   start    stop strand  \
# 0       RNCMPT00073  chr12:132725668-132743156    9915    9922      -
# 1       RNCMPT00073   chr2:127701027-127764422   32670   32677      -
# 2       RNCMPT00073   chr5:179813034-179838078    7767    7774      +
# 3       RNCMPT00073     chr1:19338775-19374171   10364   10371      +
# 4       RNCMPT00073  chr10:119104987-119137172   17298   17305      +
# ...             ...                        ...     ...     ...    ...
# 98347   RNCMPT00187   chr2:142947422-143049440   88322   88328      -
# 98348   RNCMPT00187   chr8:124550784-124699289   97641   97647      -
# 98349   RNCMPT00187   chr8:124550784-124699289   98019   98025      -
# 98350   RNCMPT00187   chr8:124550784-124699289  140884  140890      -
# 98351   RNCMPT00187   chr8:124550784-124699289  143830  143836      -
#
#          score   p-value  q-value matched sequence
# 0      13.3929  0.000010   1.0000         GACGACGG
# ...

# %%
signdf=onedf[onedf['q-value']<0.05]
signdf
# Out:
#       #pattern name             sequence name   start    stop strand    score  \
# 6       RNCMPT00072  chrX:119583378-119584425      33      40      -  11.7195
# 7       RNCMPT00072     chr17:1569268-1574375     238     245      -  11.7195
# 8       RNCMPT00072  chr1:156137868-156140081     445     452      -  11.7195
# 9       RNCMPT00072    chr1:52086988-52088428     459     466      -  11.7195
# 10      RNCMPT00072  chr9:122239998-122241638     890     897      -  11.7195
# ...             ...                       ...     ...     ...    ...      ...
# 92350   RNCMPT00012  chr8:124550784-124699289  123948  123954      +  11.0342
# 92351   RNCMPT00012  chr8:124550784-124699289  125936  125942      +  11.0342
# 92352   RNCMPT00012  chr8:124550784-124699289  133325  133331      +  11.0342
# 92353   RNCMPT00012  chr8:124550784-124699289  135612  135618      +  11.0342
# 92354   RNCMPT00012  chr8:124550784-124699289  147723  147729      +  11.0342
#
# ...

# %%
signdf.drop_duplicates(['#pattern name','sequence name'],inplace=True)
signdf
# Out:
# /tmp/ipykernel_427618/3529727461.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   signdf.drop_duplicates(['#pattern name','sequence name'],inplace=True)
#       #pattern name             sequence name  start  stop strand    score  \
# 6       RNCMPT00072  chrX:119583378-119584425     33    40      -  11.7195
# 7       RNCMPT00072     chr17:1569268-1574375    238   245      -  11.7195
# 8       RNCMPT00072  chr1:156137868-156140081    445   452      -  11.7195
# 9       RNCMPT00072    chr1:52086988-52088428    459   466      -  11.7195
# 10      RNCMPT00072  chr9:122239998-122241638    890   897      -  11.7195
# ...             ...                       ...    ...   ...    ...      ...
# 91117   RNCMPT00012  chr2:234493041-234495128   1710  1716      +  11.0342
# ...

# %%
rbpdf=pd.DataFrame(signdf['#pattern name'].value_counts())
rbpdf
# Out:
#                count
# #pattern name
# RNCMPT00012      231
# RNCMPT00158      231
# RNCMPT00155      228
# RNCMPT00064      228
# RNCMPT00165      225
# RNCMPT00079      225
# RNCMPT00159      220
# RNCMPT00077      220
# RNCMPT00117      214
# RNCMPT00112      214
# RNCMPT00086      214
# RNCMPT00160      192
# RNCMPT00044      189
# RNCMPT00089      187
# RNCMPT00019      187
# RNCMPT00268      183
# RNCMPT00004      179
# RNCMPT00166      179
# RNCMPT00027      179
# RNCMPT00178      179
# RNCMPT00072      173
# RNCMPT00088      133

# %%
rbpdf.reset_index(inplace=True)
rbpdf
# Out:
#    #pattern name  count
# 0    RNCMPT00012    231
# 1    RNCMPT00158    231
# 2    RNCMPT00155    228
# 3    RNCMPT00064    228
# 4    RNCMPT00165    225
# 5    RNCMPT00079    225
# 6    RNCMPT00159    220
# 7    RNCMPT00077    220
# 8    RNCMPT00117    214
# 9    RNCMPT00112    214
# 10   RNCMPT00086    214
# 11   RNCMPT00160    192
# 12   RNCMPT00044    189
# 13   RNCMPT00089    187
# 14   RNCMPT00019    187
# 15   RNCMPT00268    183
# 16   RNCMPT00004    179
# 17   RNCMPT00166    179
# 18   RNCMPT00027    179
# 19   RNCMPT00178    179
# 20   RNCMPT00072    173
# 21   RNCMPT00088    133

# %%
rbpdf.columns=['#pattern name','count']
rbpdf
# Out:
#    #pattern name  count
# 0    RNCMPT00012    231
# 1    RNCMPT00158    231
# 2    RNCMPT00155    228
# 3    RNCMPT00064    228
# 4    RNCMPT00165    225
# 5    RNCMPT00079    225
# 6    RNCMPT00159    220
# 7    RNCMPT00077    220
# 8    RNCMPT00117    214
# 9    RNCMPT00112    214
# 10   RNCMPT00086    214
# 11   RNCMPT00160    192
# 12   RNCMPT00044    189
# 13   RNCMPT00089    187
# 14   RNCMPT00019    187
# 15   RNCMPT00268    183
# 16   RNCMPT00004    179
# 17   RNCMPT00166    179
# 18   RNCMPT00027    179
# 19   RNCMPT00178    179
# 20   RNCMPT00072    173
# 21   RNCMPT00088    133

# %%
df=pd.read_csv('/mnt/ruiyanhou/nfs_share2/three_primer/ESCC/ERCC_part/RBP/Ray2013_rbp_Homo_sapiens.dna_encoded.meme',header=None)
df
# Out:
#                                                       0
# 0     MEME version 5.5.5 (Thu Sep 14 08:48:04 2023 +...
# 1                                        ALPHABET= ACGT
# 2                                          strands: + -
# 3     Background letter frequencies (from uniform ba...
# 4              A 0.25000 C 0.25000 G 0.25000 T 0.25000
# ...                                                 ...
# 1027     0.019924\t  0.019924\t  0.129433\t  0.830720\t
# 1028     0.019924\t  0.572493\t  0.387660\t  0.019924\t
# 1029     0.019924\t  0.019924\t  0.656335\t  0.303817\t
# 1030     0.066065\t  0.066065\t  0.152230\t  0.715640\t
# 1031  URL http://hugheslab.ccbr.utoronto.ca/suppleme...
#
# [1032 rows x 1 columns]

# %%
selectdf=df[df[0].str.contains('MOTIF')]
selectdf
# Out:
#                               0
# 5        MOTIF RNCMPT00001 A1CF
# 15     MOTIF RNCMPT00002 ANKHD1
# 25    MOTIF RNCMPT00004 BRUNOL4
# 35    MOTIF RNCMPT00166 BRUNOL5
# 45    MOTIF RNCMPT00187 BRUNOL6
# ...                         ...
# 981      MOTIF RNCMPT00084 YBX2
# 991    MOTIF RNCMPT00085 ZC3H10
# 1001   MOTIF RNCMPT00086 ZC3H14
# 1011    MOTIF RNCMPT00087 ZCRB1
# 1022   MOTIF RNCMPT00164 ZNF638
#
# [102 rows x 1 columns]

# %%
selectdf['#pattern name']=selectdf[0].str.split(' ',expand=True)[1]
selectdf['RBP']=selectdf[0].str.split(' ',expand=True)[2]
selectdf
# Out:
# /tmp/ipykernel_427618/2830881180.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selectdf['#pattern name']=selectdf[0].str.split(' ',expand=True)[1]
# /tmp/ipykernel_427618/2830881180.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selectdf['RBP']=selectdf[0].str.split(' ',expand=True)[2]
#                               0 #pattern name      RBP
# 5        MOTIF RNCMPT00001 A1CF   RNCMPT00001     A1CF
# 15     MOTIF RNCMPT00002 ANKHD1   RNCMPT00002   ANKHD1
# ...

# %%
selectdf=selectdf[['#pattern name','RBP']]
selectdf
# Out:
#      #pattern name      RBP
# 5      RNCMPT00001     A1CF
# 15     RNCMPT00002   ANKHD1
# 25     RNCMPT00004  BRUNOL4
# 35     RNCMPT00166  BRUNOL5
# 45     RNCMPT00187  BRUNOL6
# ...            ...      ...
# 981    RNCMPT00084     YBX2
# 991    RNCMPT00085   ZC3H10
# 1001   RNCMPT00086   ZC3H14
# 1011   RNCMPT00087    ZCRB1
# 1022   RNCMPT00164   ZNF638
#
# [102 rows x 2 columns]

# %%
allrbpdf=rbpdf.merge(selectdf,on='#pattern name')
allrbpdf
# Out:
#    #pattern name  count      RBP
# 0    RNCMPT00012    231    CPEB2
# 1    RNCMPT00158    231    CPEB4
# 2    RNCMPT00155    228   PABPC1
# 3    RNCMPT00064    228    SART3
# 4    RNCMPT00165    225     TIA1
# 5    RNCMPT00079    225    U2AF2
# 6    RNCMPT00159    220     RALY
# 7    RNCMPT00077    220     TIA1
# 8    RNCMPT00117    214      HuR
# 9    RNCMPT00112    214      HuR
# 10   RNCMPT00086    214   ZC3H14
# 11   RNCMPT00160    192  HNRNPH2
# 12   RNCMPT00044    189    PCBP2
# 13   RNCMPT00089    187   SRSF10
# 14   RNCMPT00019    187   SRSF10
# 15   RNCMPT00268    183    PTBP1
# 16   RNCMPT00004    179  BRUNOL4
# 17   RNCMPT00166    179  BRUNOL5
# 18   RNCMPT00027    179   HNRNPL
# 19   RNCMPT00178    179   HNRPLL
# 20   RNCMPT00072    173    SRSF2
# 21   RNCMPT00088    133   SRSF10

# %%
#allrbpdf.to_csv('/mnt/ruiyanhou/nfs_share2/three_primer/ESCC/ERCC_part/RBP/gap_binding_RBP.csv')


import seaborn as sns
import matplotlib.pyplot as plt

plt.rcParams['font.size']=16

fig=plt.subplots(figsize=(10,5))
sns.barplot(allrbpdf, x="RBP", y="count",color='darkcyan')
plt.xticks(rotation=45)
plt.xlabel("")
plt.ylabel("Binding frequency")
#plt.savefig('/mnt/ruiyanhou/nfs_share2/three_primer/ESCC/ERCC_part/RBP/total_gap_gene_binding.pdf',dpi=300,bbox_inches='tight')
plt.show()

# %% [markdown]
# # Plot heatmap of these RBP

# %%
import pandas as pd
import scanpy as sc

# %%
adata=sc.read('/mnt/ruiyanhou/nfs_share2/three_primer/ESCC/ERCC_part/ERCC_gene_exp.h5ad')
adata
# Out:
# /mnt/ruiyanhou/nfs_share2/conda_env/envs/Py39/lib/python3.9/site-packages/anndata-0.10.3-py3.9.egg/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# AnnData object with n_obs × n_vars = 89313 × 62700
#     obs: 'patient', 'nCount_RNA', 'nFeature_RNA', 'percent.mt', 'RNA_snn_res.2.6', 'seurat_clusters', 'celltype', 'PatientType', 'SampleType', 'stage'
#     var: 'gene_ids', 'feature_types', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'celltype_colors', 'hvg', 'log1p', 'raw_count'
#     obsm: 'X_umap'

# %%
adata.var.index
# Out:
# Index(['DDX11L2', 'DDX11L1', 'WASH7P', 'MIR6859-1', 'MIR1302-2HG', 'MIR1302-2',
#        'FAM138A', 'OR4G4P', 'ENSG00000290826', 'OR4G11P',
#        ...
#        'MT-ND4', 'MT-TH', 'MT-TS2', 'MT-TL2', 'MT-ND5', 'MT-ND6', 'MT-TE',
#        'MT-CYB', 'MT-TT', 'MT-TP'],
#       dtype='object', length=62700)

# %%
rbpdf=pd.read_csv('/mnt/ruiyanhou/nfs_share2/three_primer/ESCC/ERCC_part/RBP/gap_binding_RBP.csv',index_col=0)
rbpdf
# Out:
#    #pattern name  count      RBP
# 0    RNCMPT00012    231    CPEB2
# 1    RNCMPT00158    231    CPEB4
# 2    RNCMPT00155    228   PABPC1
# 3    RNCMPT00064    228    SART3
# 4    RNCMPT00165    225     TIA1
# 5    RNCMPT00079    225    U2AF2
# 6    RNCMPT00159    220     RALY
# 7    RNCMPT00077    220     TIA1
# 8    RNCMPT00117    214      HuR
# 9    RNCMPT00112    214      HuR
# 10   RNCMPT00086    214   ZC3H14
# 11   RNCMPT00160    192  HNRNPH2
# 12   RNCMPT00044    189    PCBP2
# 13   RNCMPT00089    187   SRSF10
# 14   RNCMPT00019    187   SRSF10
# 15   RNCMPT00268    183    PTBP1
# 16   RNCMPT00004    179  BRUNOL4
# 17   RNCMPT00166    179  BRUNOL5
# 18   RNCMPT00027    179   HNRNPL
# 19   RNCMPT00178    179   HNRPLL
# 20   RNCMPT00072    173    SRSF2
# 21   RNCMPT00088    133   SRSF10

# %%
rbpdf['RBP_other_name']=rbpdf['RBP']
rbpdf
# Out:
#    #pattern name  count      RBP RBP_other_name
# 0    RNCMPT00012    231    CPEB2          CPEB2
# 1    RNCMPT00158    231    CPEB4          CPEB4
# 2    RNCMPT00155    228   PABPC1         PABPC1
# 3    RNCMPT00064    228    SART3          SART3
# 4    RNCMPT00165    225     TIA1           TIA1
# 5    RNCMPT00079    225    U2AF2          U2AF2
# 6    RNCMPT00159    220     RALY           RALY
# 7    RNCMPT00077    220     TIA1           TIA1
# 8    RNCMPT00117    214      HuR            HuR
# 9    RNCMPT00112    214      HuR            HuR
# 10   RNCMPT00086    214   ZC3H14         ZC3H14
# 11   RNCMPT00160    192  HNRNPH2        HNRNPH2
# 12   RNCMPT00044    189    PCBP2          PCBP2
# 13   RNCMPT00089    187   SRSF10         SRSF10
# 14   RNCMPT00019    187   SRSF10         SRSF10
# 15   RNCMPT00268    183    PTBP1          PTBP1
# 16   RNCMPT00004    179  BRUNOL4        BRUNOL4
# 17   RNCMPT00166    179  BRUNOL5        BRUNOL5
# 18   RNCMPT00027    179   HNRNPL         HNRNPL
# ...

# %%
rbpdf['RBP_other_name'].replace({'HuR':'ENSG00000248388','HNRPLL':'HNRNPLL','BRUNOL5':'CELF5','BRUNOL4':'CELF4'},inplace=True)
rbpdf
# Out:
#    #pattern name  count      RBP   RBP_other_name
# 0    RNCMPT00012    231    CPEB2            CPEB2
# 1    RNCMPT00158    231    CPEB4            CPEB4
# 2    RNCMPT00155    228   PABPC1           PABPC1
# 3    RNCMPT00064    228    SART3            SART3
# 4    RNCMPT00165    225     TIA1             TIA1
# 5    RNCMPT00079    225    U2AF2            U2AF2
# 6    RNCMPT00159    220     RALY             RALY
# 7    RNCMPT00077    220     TIA1             TIA1
# 8    RNCMPT00117    214      HuR  ENSG00000248388
# 9    RNCMPT00112    214      HuR  ENSG00000248388
# 10   RNCMPT00086    214   ZC3H14           ZC3H14
# 11   RNCMPT00160    192  HNRNPH2          HNRNPH2
# 12   RNCMPT00044    189    PCBP2            PCBP2
# 13   RNCMPT00089    187   SRSF10           SRSF10
# 14   RNCMPT00019    187   SRSF10           SRSF10
# 15   RNCMPT00268    183    PTBP1            PTBP1
# 16   RNCMPT00004    179  BRUNOL4            CELF4
# 17   RNCMPT00166    179  BRUNOL5            CELF5
# ...

# %%
rbpdf.rename(columns={'RBP_other_name':'gene_name'},inplace=True)
rbpdf
# Out:
#    #pattern name  count      RBP        gene_name
# 0    RNCMPT00012    231    CPEB2            CPEB2
# 1    RNCMPT00158    231    CPEB4            CPEB4
# 2    RNCMPT00155    228   PABPC1           PABPC1
# 3    RNCMPT00064    228    SART3            SART3
# 4    RNCMPT00165    225     TIA1             TIA1
# 5    RNCMPT00079    225    U2AF2            U2AF2
# 6    RNCMPT00159    220     RALY             RALY
# 7    RNCMPT00077    220     TIA1             TIA1
# 8    RNCMPT00117    214      HuR  ENSG00000248388
# 9    RNCMPT00112    214      HuR  ENSG00000248388
# 10   RNCMPT00086    214   ZC3H14           ZC3H14
# 11   RNCMPT00160    192  HNRNPH2          HNRNPH2
# 12   RNCMPT00044    189    PCBP2            PCBP2
# 13   RNCMPT00089    187   SRSF10           SRSF10
# 14   RNCMPT00019    187   SRSF10           SRSF10
# 15   RNCMPT00268    183    PTBP1            PTBP1
# 16   RNCMPT00004    179  BRUNOL4            CELF4
# 17   RNCMPT00166    179  BRUNOL5            CELF5
# ...

# %%
refdf=pd.read_csv('/mnt/ruiyanhou/nfs_share2/three_primer/ESCC/run_scTail/scTail_callpeak/SRR16796861/ref_file/ref_gene.tsv',delimiter='\t')
refdf=refdf[['gene_id','gene_name']]
refdf
# Out:
#                  gene_id    gene_name
# 0      ENSG00000290825.1      DDX11L2
# 1      ENSG00000223972.6      DDX11L1
# 2      ENSG00000243485.5  MIR1302-2HG
# 3      ENSG00000284332.1    MIR1302-2
# 4      ENSG00000268020.3       OR4G4P
# ...                  ...          ...
# 62576  ENSG00000231514.1       CCNQP2
# 62577  ENSG00000292364.1       AMD1P2
# 62578  ENSG00000292367.1      ELOCP24
# 62579  ENSG00000292368.1      TRPC6P1
# 62580  ENSG00000292370.1       WASIR1
#
# [62581 rows x 2 columns]

# %%
outdf=rbpdf.merge(refdf,on='gene_name')
outdf
# Out:
#    #pattern name  count      RBP        gene_name             gene_id
# 0    RNCMPT00012    231    CPEB2            CPEB2  ENSG00000137449.17
# 1    RNCMPT00158    231    CPEB4            CPEB4  ENSG00000113742.14
# 2    RNCMPT00155    228   PABPC1           PABPC1  ENSG00000070756.17
# 3    RNCMPT00064    228    SART3            SART3  ENSG00000075856.12
# 4    RNCMPT00165    225     TIA1             TIA1  ENSG00000116001.17
# 5    RNCMPT00077    220     TIA1             TIA1  ENSG00000116001.17
# 6    RNCMPT00079    225    U2AF2            U2AF2  ENSG00000063244.14
# 7    RNCMPT00159    220     RALY             RALY  ENSG00000125970.12
# 8    RNCMPT00117    214      HuR  ENSG00000248388   ENSG00000248388.5
# 9    RNCMPT00112    214      HuR  ENSG00000248388   ENSG00000248388.5
# 10   RNCMPT00086    214   ZC3H14           ZC3H14  ENSG00000100722.20
# 11   RNCMPT00160    192  HNRNPH2          HNRNPH2   ENSG00000126945.9
# ...

# %%
#outdf.to_csv('/mnt/ruiyanhou/nfs_share2/three_primer/ESCC/ERCC_part/RBP/gap_binding_RBP_withanno.csv')

selectadata=adata[:,adata.var['gene_ids'].isin(outdf['gene_id'])]
selectadata
# Out:
# View of AnnData object with n_obs × n_vars = 89313 × 18
#     obs: 'patient', 'nCount_RNA', 'nFeature_RNA', 'percent.mt', 'RNA_snn_res.2.6', 'seurat_clusters', 'celltype', 'PatientType', 'SampleType', 'stage'
#     var: 'gene_ids', 'feature_types', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'celltype_colors', 'hvg', 'log1p', 'raw_count'
#     obsm: 'X_umap'

# %%
selectadata.obs['celltype'].unique()
# Out:
# ['Fibroblasts', 'Myeloid cells', 'T cells', 'B cells', 'Plasma cells', ..., 'Endothelial cells', 'Cycling cells', 'Mast cells', 'Smooth muscle cells', 'pDC']
# Length: 11
# Categories (11, object): ['B cells', 'Cycling cells', 'Endothelial cells', 'Epithelial cell', ..., 'Plasma cells', 'Smooth muscle cells', 'T cells', 'pDC']

# %%
fibrablastadata=selectadata[selectadata.obs['celltype']=='Epithelial cell',:]
fibrablastadata
# Out:
# View of AnnData object with n_obs × n_vars = 6561 × 18
#     obs: 'patient', 'nCount_RNA', 'nFeature_RNA', 'percent.mt', 'RNA_snn_res.2.6', 'seurat_clusters', 'celltype', 'PatientType', 'SampleType', 'stage'
#     var: 'gene_ids', 'feature_types', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'celltype_colors', 'hvg', 'log1p', 'raw_count'
#     obsm: 'X_umap'

# %%
fibrablastadata.var.index

import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import gcf

# %%
alldfls=[]
for patientid in fibrablastadata.obs['PatientType'].unique():
    for sampletype in fibrablastadata.obs['SampleType'].unique():
        onepatientadata=fibrablastadata[(fibrablastadata.obs['PatientType']==patientid)&(fibrablastadata.obs['SampleType']==sampletype),:]
        rbpexp=np.mean(onepatientadata.X.toarray(),axis=0)
        coltitle=str(patientid)+'_'+sampletype
        rbpexpdf=pd.DataFrame(rbpexp,index=onepatientadata.var.index,columns=[coltitle])
    
        alldfls.append(rbpexpdf)
# Out:
# /mnt/ruiyanhou/nfs_share2/conda_env/envs/Py39/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /mnt/ruiyanhou/nfs_share2/conda_env/envs/Py39/lib/python3.9/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(

# %%
alldfls

finaldf=pd.concat(alldfls,axis=1)
finaldf
# Out:
#                  686_Tumor  686_Normal  658_Tumor  658_Normal  585_Tumor  \
# SRSF10            0.471918    0.211776   0.412247    0.116850   0.317062
# HNRNPLL           0.018464    0.074936   0.062888    0.079283   0.089045
# TIA1              0.098868    0.084554   0.113022    0.066984   0.111419
# CPEB2             0.124774    0.148681   0.175082    0.134659   0.020785
# ENSG00000248388   0.000000    0.000000   0.000000    0.000000   0.000000
# CPEB4             0.323229    0.422569   0.295988    0.345353   0.028569
# PABPC1            2.209201    2.722514   1.749546    2.219453   2.021236
# PCBP2             0.931415    0.673154   0.816321    0.546906   0.769650
# SART3             0.074924    0.065953   0.070299    0.028384   0.069651
# ZC3H14            0.131861    0.023568   0.125051    0.064979   0.152426
# SRSF2             1.100046    0.477174   0.842367    0.548431   1.045856
# CELF4             0.000000    0.009660   0.006779    0.000000   0.003805
# ...

# %%
finaldf.dropna(how='any',inplace=True,axis=1)
finaldf
# Out:
#                  686_Tumor  686_Normal  658_Tumor  658_Normal  585_Tumor  \
# SRSF10            0.471918    0.211776   0.412247    0.116850   0.317062
# HNRNPLL           0.018464    0.074936   0.062888    0.079283   0.089045
# TIA1              0.098868    0.084554   0.113022    0.066984   0.111419
# CPEB2             0.124774    0.148681   0.175082    0.134659   0.020785
# ENSG00000248388   0.000000    0.000000   0.000000    0.000000   0.000000
# CPEB4             0.323229    0.422569   0.295988    0.345353   0.028569
# PABPC1            2.209201    2.722514   1.749546    2.219453   2.021236
# PCBP2             0.931415    0.673154   0.816321    0.546906   0.769650
# SART3             0.074924    0.065953   0.070299    0.028384   0.069651
# ZC3H14            0.131861    0.023568   0.125051    0.064979   0.152426
# SRSF2             1.100046    0.477174   0.842367    0.548431   1.045856
# CELF4             0.000000    0.009660   0.006779    0.000000   0.003805
# ...

# %%
import seaborn as sns

# %%
columndf=pd.DataFrame(finaldf.columns,columns=['name'])
columndf
# Out:
#           name
# 0    686_Tumor
# 1   686_Normal
# 2    658_Tumor
# 3   658_Normal
# 4    585_Tumor
# 5   585_Normal
# 6    986_Tumor
# 7   986_Normal
# 8    944_Tumor
# 9   944_Normal
# 10   866_Tumor
# 11  866_Normal
# 12   865_Tumor
# 13   846_Tumor
# 14  846_Normal
# 15   836_Tumor
# 16   787_Tumor
# 17  787_Normal
# 18     9_Tumor
# 19    9_Normal

# %%
columndf['condition']=columndf['name'].str.split('_',expand=True)[1]
columndf
# Out:
#           name condition
# 0    686_Tumor     Tumor
# 1   686_Normal    Normal
# 2    658_Tumor     Tumor
# 3   658_Normal    Normal
# 4    585_Tumor     Tumor
# 5   585_Normal    Normal
# 6    986_Tumor     Tumor
# 7   986_Normal    Normal
# 8    944_Tumor     Tumor
# 9   944_Normal    Normal
# 10   866_Tumor     Tumor
# 11  866_Normal    Normal
# 12   865_Tumor     Tumor
# 13   846_Tumor     Tumor
# 14  846_Normal    Normal
# 15   836_Tumor     Tumor
# 16   787_Tumor     Tumor
# 17  787_Normal    Normal
# 18     9_Tumor     Tumor
# 19    9_Normal    Normal

# %%
columndf.sort_values(['condition'],inplace=True)
columndf
# Out:
#           name condition
# 9   944_Normal    Normal
# 17  787_Normal    Normal
# 14  846_Normal    Normal
# 11  866_Normal    Normal
# 7   986_Normal    Normal
# 19    9_Normal    Normal
# 3   658_Normal    Normal
# 1   686_Normal    Normal
# 5   585_Normal    Normal
# 6    986_Tumor     Tumor
# 4    585_Tumor     Tumor
# 8    944_Tumor     Tumor
# 18     9_Tumor     Tumor
# 10   866_Tumor     Tumor
# 12   865_Tumor     Tumor
# 13   846_Tumor     Tumor
# 2    658_Tumor     Tumor
# 15   836_Tumor     Tumor
# 16   787_Tumor     Tumor
# 0    686_Tumor     Tumor

# %%
lut1=dict(zip(set(columndf['condition']), ['gold','lightseagreen']))
column_colors=columndf['condition'].map(lut1)

column_colors
# Out:
# 9     lightseagreen
# 17    lightseagreen
# 14    lightseagreen
# 11    lightseagreen
# 7     lightseagreen
# 19    lightseagreen
# 3     lightseagreen
# 1     lightseagreen
# 5     lightseagreen
# 6              gold
# 4              gold
# 8              gold
# 18             gold
# 10             gold
# 12             gold
# 13             gold
# 2              gold
# 15             gold
# 16             gold
# 0              gold
# Name: condition, dtype: object

# %%
finaldf=finaldf[columndf['name'].tolist()]
finaldf
# Out:
#                  944_Normal  787_Normal  846_Normal  866_Normal  986_Normal  \
# SRSF10             0.204766    0.293747    0.387318    0.142219    0.282675
# HNRNPLL            0.111431    0.073496    0.091077    0.034428    0.077142
# TIA1               0.096987    0.069678    0.108375    0.050976    0.000000
# CPEB2              0.074105    0.114929    0.056119    0.068187    0.000000
# ENSG00000248388    0.000000    0.000000    0.000000    0.000000    0.000000
# CPEB4              0.471655    0.189331    0.250398    0.351353    0.013367
# PABPC1             1.991565    1.667319    2.473913    2.834803    2.161288
# PCBP2              0.659622    0.747364    0.887380    0.458754    0.865492
# SART3              0.038749    0.078584    0.174252    0.014907    0.089567
# ZC3H14             0.091460    0.065787    0.029211    0.045571    0.055391
# SRSF2              0.638707    0.767266    0.697576    0.571546    1.392847
# ...

# %%
finaldf.reset_index(inplace=True)
finaldf
# Out:
#               index  944_Normal  787_Normal  846_Normal  866_Normal  \
# 0            SRSF10    0.204766    0.293747    0.387318    0.142219
# 1           HNRNPLL    0.111431    0.073496    0.091077    0.034428
# 2              TIA1    0.096987    0.069678    0.108375    0.050976
# 3             CPEB2    0.074105    0.114929    0.056119    0.068187
# 4   ENSG00000248388    0.000000    0.000000    0.000000    0.000000
# 5             CPEB4    0.471655    0.189331    0.250398    0.351353
# 6            PABPC1    1.991565    1.667319    2.473913    2.834803
# 7             PCBP2    0.659622    0.747364    0.887380    0.458754
# 8             SART3    0.038749    0.078584    0.174252    0.014907
# 9            ZC3H14    0.091460    0.065787    0.029211    0.045571
# 10            SRSF2    0.638707    0.767266    0.697576    0.571546
# 11            CELF4    0.112756    0.026571    0.000000    0.000000
# 12            PTBP1    0.160022    0.329436    0.230025    0.104104
# ...

# %%
finaldf.rename(columns={'index':'gene_name'},inplace=True)
finaldf
# Out:
# /tmp/ipykernel_427618/701024986.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   finaldf.rename(columns={'index':'gene_name'},inplace=True)
#           gene_name  944_Normal  787_Normal  846_Normal  866_Normal  \
# 0            SRSF10    0.204766    0.293747    0.387318    0.142219
# 1           HNRNPLL    0.111431    0.073496    0.091077    0.034428
# 2              TIA1    0.096987    0.069678    0.108375    0.050976
# 3             CPEB2    0.074105    0.114929    0.056119    0.068187
# 4   ENSG00000248388    0.000000    0.000000    0.000000    0.000000
# 5             CPEB4    0.471655    0.189331    0.250398    0.351353
# 6            PABPC1    1.991565    1.667319    2.473913    2.834803
# 7             PCBP2    0.659622    0.747364    0.887380    0.458754
# ...

# %%
outdf=outdf[['RBP','gene_name']]
outdf
# Out:
#         RBP        gene_name
# 0     CPEB2            CPEB2
# 1     CPEB4            CPEB4
# 2    PABPC1           PABPC1
# 3     SART3            SART3
# 4      TIA1             TIA1
# 5      TIA1             TIA1
# 6     U2AF2            U2AF2
# 7      RALY             RALY
# 8       HuR  ENSG00000248388
# 9       HuR  ENSG00000248388
# 10   ZC3H14           ZC3H14
# 11  HNRNPH2          HNRNPH2
# 12    PCBP2            PCBP2
# 13   SRSF10           SRSF10
# 14   SRSF10           SRSF10
# 15   SRSF10           SRSF10
# 16    PTBP1            PTBP1
# 17  BRUNOL4            CELF4
# 18  BRUNOL5            CELF5
# 19   HNRNPL           HNRNPL
# 20   HNRPLL          HNRNPLL
# 21    SRSF2            SRSF2

# %%
outdf.drop_duplicates(['RBP','gene_name'],inplace=True)
outdf
# Out:
# /tmp/ipykernel_427618/37656926.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outdf.drop_duplicates(['RBP','gene_name'],inplace=True)
#         RBP        gene_name
# 0     CPEB2            CPEB2
# 1     CPEB4            CPEB4
# 2    PABPC1           PABPC1
# 3     SART3            SART3
# 4      TIA1             TIA1
# 6     U2AF2            U2AF2
# 7      RALY             RALY
# 8       HuR  ENSG00000248388
# 10   ZC3H14           ZC3H14
# 11  HNRNPH2          HNRNPH2
# 12    PCBP2            PCBP2
# 13   SRSF10           SRSF10
# 16    PTBP1            PTBP1
# 17  BRUNOL4            CELF4
# 18  BRUNOL5            CELF5
# 19   HNRNPL           HNRNPL
# 20   HNRPLL          HNRNPLL
# 21    SRSF2            SRSF2

# %%
len(outdf)
# Out:
# 18

# %%
finaldf=outdf.merge(finaldf,on='gene_name')
finaldf
# Out:
#         RBP        gene_name  944_Normal  787_Normal  846_Normal  866_Normal  \
# 0     CPEB2            CPEB2    0.074105    0.114929    0.056119    0.068187
# 1     CPEB4            CPEB4    0.471655    0.189331    0.250398    0.351353
# 2    PABPC1           PABPC1    1.991565    1.667319    2.473913    2.834803
# 3     SART3            SART3    0.038749    0.078584    0.174252    0.014907
# 4      TIA1             TIA1    0.096987    0.069678    0.108375    0.050976
# 5     U2AF2            U2AF2    0.163941    0.128254    0.013846    0.053674
# 6      RALY             RALY    0.287651    0.318892    0.296882    0.217892
# 7       HuR  ENSG00000248388    0.000000    0.000000    0.000000    0.000000
# 8    ZC3H14           ZC3H14    0.091460    0.065787    0.029211    0.045571
# 9   HNRNPH2          HNRNPH2    0.325095    0.307689    0.139521    0.296486
# 10    PCBP2            PCBP2    0.659622    0.747364    0.887380    0.458754
# ...

# %%
finaldf.drop(labels='gene_name',inplace=True,axis=1)
finaldf
# Out:
#         RBP  944_Normal  787_Normal  846_Normal  866_Normal  986_Normal  \
# 0     CPEB2    0.074105    0.114929    0.056119    0.068187    0.000000
# 1     CPEB4    0.471655    0.189331    0.250398    0.351353    0.013367
# 2    PABPC1    1.991565    1.667319    2.473913    2.834803    2.161288
# 3     SART3    0.038749    0.078584    0.174252    0.014907    0.089567
# 4      TIA1    0.096987    0.069678    0.108375    0.050976    0.000000
# 5     U2AF2    0.163941    0.128254    0.013846    0.053674    0.089120
# 6      RALY    0.287651    0.318892    0.296882    0.217892    0.388801
# 7       HuR    0.000000    0.000000    0.000000    0.000000    0.000000
# 8    ZC3H14    0.091460    0.065787    0.029211    0.045571    0.055391
# 9   HNRNPH2    0.325095    0.307689    0.139521    0.296486    0.274399
# 10    PCBP2    0.659622    0.747364    0.887380    0.458754    0.865492
# 11   SRSF10    0.204766    0.293747    0.387318    0.142219    0.282675
# ...

# %%
finaldf.set_index('RBP',inplace=True)
finaldf
# Out:
#          944_Normal  787_Normal  846_Normal  866_Normal  986_Normal  9_Normal  \
# RBP
# CPEB2      0.074105    0.114929    0.056119    0.068187    0.000000  0.117500
# CPEB4      0.471655    0.189331    0.250398    0.351353    0.013367  0.604786
# PABPC1     1.991565    1.667319    2.473913    2.834803    2.161288  2.415714
# SART3      0.038749    0.078584    0.174252    0.014907    0.089567  0.030160
# TIA1       0.096987    0.069678    0.108375    0.050976    0.000000  0.049349
# U2AF2      0.163941    0.128254    0.013846    0.053674    0.089120  0.096818
# RALY       0.287651    0.318892    0.296882    0.217892    0.388801  0.273109
# HuR        0.000000    0.000000    0.000000    0.000000    0.000000  0.000000
# ZC3H14     0.091460    0.065787    0.029211    0.045571    0.055391  0.015794
# HNRNPH2    0.325095    0.307689    0.139521    0.296486    0.274399  0.511146
# PCBP2      0.659622    0.747364    0.887380    0.458754    0.865492  0.482021
# ...

# %%
plt.rcParams['font.size']=15

# %%
fig=sns.clustermap(finaldf,metric='euclidean',method='average',cmap='YlGnBu',col_colors=[column_colors],col_cluster=True,yticklabels=True,row_cluster=True,
                  figsize=(6,9),colors_ratio=0.02)

#fig=sns.clustermap(fisherplotdf,metric='euclidean',method='ward',row_colors=[row_colors],col_colors=column_colors,cmap='YlGnBu',col_cluster=True)
#fig.ax_col_dendrogram.set_visible(False)
fig.ax_heatmap.set_xlabel(" ")
fig.ax_heatmap.set_ylabel(" ")





for label in columndf['condition'].unique():
    fig.ax_row_dendrogram.bar(0, 0, color=lut1[label],label=label, linewidth=0)
l2=fig.ax_row_dendrogram.legend(title='Condition', loc="center", ncol=2, bbox_to_anchor=(0.82, 0.97), bbox_transform=gcf().transFigure) 

#fig.savefig('/mnt/ruiyanhou/nfs_share2/three_primer/ESCC/ERCC_part/RBP/gap_sequence_tumor_normal_heatmap.pdf',dpi=300,bbox_inches='tight')
plt.show()

# %%
finaldf

finaldfT=finaldf.T
finaldfT

finaldfT.reset_index(inplace=True)
finaldfT

finaldfT['condition']=finaldfT['index'].str.split('_',expand=True)[1]
finaldfT

normaldf=finaldfT[finaldfT['condition']=='Normal']
normaldf

tumordf=finaldfT[finaldfT['condition']=='Tumor']
tumordf

from scipy import stats

for rbp in finaldfT.columns.tolist()[1:-1]:
    print(rbp)
    normalnp=normaldf[[rbp]].values
    tumornp=tumordf[[rbp]].values
    print(stats.ttest_ind(normalnp,tumornp))
# Out:
# CPEB2
# TtestResult(statistic=array([0.8787236], dtype=float32), pvalue=array([0.39113078], dtype=float32), df=array([18.]))
# CPEB4
# TtestResult(statistic=array([2.4778585], dtype=float32), pvalue=array([0.02335728], dtype=float32), df=array([18.]))
# PABPC1
# TtestResult(statistic=array([3.1003675], dtype=float32), pvalue=array([0.00617435], dtype=float32), df=array([18.]))
# SART3
# TtestResult(statistic=array([-1.5121192], dtype=float32), pvalue=array([0.14786208], dtype=float32), df=array([18.]))
# TIA1
# TtestResult(statistic=array([-2.0915241], dtype=float32), pvalue=array([0.05092845], dtype=float32), df=array([18.]))
# U2AF2
# TtestResult(statistic=array([-2.5267808], dtype=float32), pvalue=array([0.02109825], dtype=float32), df=array([18.]))
# RALY
# TtestResult(statistic=array([-1.8505899], dtype=float32), pvalue=array([0.08071173], dtype=float32), df=array([18.]))
# HuR
# ...
