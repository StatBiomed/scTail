# %%
import scanpy as sc

# %%
adata=sc.read('/mnt/ruiyanhou/nfs_share2/three_primer/mouse_forelimb/PAS_exp_allcell_scale.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 70376 × 24109
#     obs: 'sample', 'barcode_used_in_scTail', 'cell_type', 'batch', 'doublet_scores', 'nCount_RNA', 'nFeatures_RNA', 'percent_mito', 'stage', 'n_counts', 'doublet_corrected_p', 'doublet_corrected_p_less_than_0_1'
#     var: 'cluster_start', 'cluster_end', 'cluster_score', 'cluster_strand', 'gene_start', 'gene_end', 'gene_score', 'gene_strand', 'original_cluster_id', 'cluster_chr', 'gene_chr', 'gene_id', 'gene_name'
#     uns: 'cell_type_colors', 'log1p', 'stage_colors'
#     obsm: 'X_tsne', 'X_umap'
#     layers: 'raw_count'

# %%
sc.pl.tsne(adata,color='cell_type',frameon=False,title="",save='mouse_forelimb_celltype')
# Out:
# /mnt/ruiyanhou/nfs_share2/conda_env/envs/Py39/lib/python3.9/site-packages/scanpy-1.9.6-py3.9.egg/scanpy/plotting/_tools/scatterplots.py:1251: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /mnt/ruiyanhou/nfs_share2/conda_env/envs/Py39/lib/python3.9/site-packages/scanpy-1.9.6-py3.9.egg/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# WARNING: saving figure to file figures/tsnemouse_forelimb_celltype.pdf

# %%
sc.pl.tsne(adata,color='stage',frameon=False,title="",save='mouse_forelimb_stage')
# Out:
# WARNING: saving figure to file figures/tsnemouse_forelimb_stage.pdf
# /mnt/ruiyanhou/nfs_share2/conda_env/envs/Py39/lib/python3.9/site-packages/scanpy-1.9.6-py3.9.egg/scanpy/plotting/_tools/scatterplots.py:1251: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /mnt/ruiyanhou/nfs_share2/conda_env/envs/Py39/lib/python3.9/site-packages/scanpy-1.9.6-py3.9.egg/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.tsne(adata,color='sample',frameon=False,title="",save='mouse_forelimb_sample')
# Out:
# WARNING: saving figure to file figures/tsnemouse_forelimb_sample.pdf
# /mnt/ruiyanhou/nfs_share2/conda_env/envs/Py39/lib/python3.9/site-packages/scanpy-1.9.6-py3.9.egg/scanpy/plotting/_tools/scatterplots.py:1251: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /mnt/ruiyanhou/nfs_share2/conda_env/envs/Py39/lib/python3.9/site-packages/scanpy-1.9.6-py3.9.egg/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
